# %%
import pandas as pd 
import numpy as nm 
import matplotlib.pyplot as plt 
import seaborn as sn

# %%
df  = pd.read_csv("Titanic-Dataset.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age']=df['Age'].fillna(value= df['Age'].mean())

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sn.histplot(data=df,x='Age')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sn.histplot(data=df,x='Fare')
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %%
# idhar 20 se lekar 40 age wale log titanic m travel kr rhe h 
# aur ticket mostly 0-50 k range m h

# %%
sn.histplot(data=df,x='Age',hue='Sex',multiple='dodge')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sn.histplot(data=df,x='Age',hue='Survived',multiple='dodge')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sn.histplot(data=df,x='Fare',hue='Sex',multiple='dodge')
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %%
sn.histplot(data=df,x='Fare',hue='Survived',multiple='dodge')
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %%
# males are more than female 
# survival rate is more for people who spend more fare 
# survival rate is more for every age group

# %%
sn.boxplot(data=df,x='Age')
# Out:
# <Axes: xlabel='Age'>

# %%
sn.boxplot(data=df,x='Fare')
# Out:
# <Axes: xlabel='Fare'>

# %%
sn.boxplot(data=df,x='Age',y='Sex')
# Out:
# <Axes: xlabel='Age', ylabel='Sex'>

# %%
sn.boxplot(data=df,x='Survived',y='Age')
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %%
sn.boxplot(data=df,x='Fare',y='Sex')
# Out:
# <Axes: xlabel='Fare', ylabel='Sex'>

# %%
sn.boxplot(data=df,x='Survived',y='Fare')
# Out:
# <Axes: xlabel='Survived', ylabel='Fare'>

# %%
sn.boxplot(data=df,x='Age',y='Sex',hue="Survived")
# Out:
# <Axes: xlabel='Age', ylabel='Sex'>

# %%
sn.boxplot(data=df,x='Survived',y='Age',hue="Sex")
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>
